# %% [markdown]
# <a href="https://colab.research.google.com/github/SalhaAlzahrani/KD_TripartiteAtten/blob/main/_KonwledgeDistillation_TransfomerTripartite_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🟢  Knowledge Distillation in Transformers with Tripartite Attention: Multiclass Brain Tumor Detection in Highly Augmented MRIs

# %%
# !pip install -U -q tensorflow-addons
# !pip install nest_asyncio
# !pip install keras-cv tensorflow --upgrade

# %%
import tensorflow as tf
from tensorflow import keras
from keras import layers
import tensorflow_addons as tfa
from keras.preprocessing import image_dataset_from_directory
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tensorflow_hub as hub
import tensorflow_datasets as tfds
import pathlib
import glob
import keras_cv
import os
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight
import math

from google.colab import drive
# Define the path to the MRI data directory
drive.mount('/content/drive', force_remount=True)

import nest_asyncio

# %% [markdown]
# ## Hyperparameters

# %%
IMG_SIZE = 224 # We'll resize input images to this size.
input_shape = (224, 224, 3)
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 64
num_epochs = 100
dropout_rate = 0.2
# DATA
BUFFER_SIZE = 512
BATCH_SIZE = 256
# AUGMENTATION
PATCH_SIZE = 6
NUM_PATCHES = (IMG_SIZE // PATCH_SIZE) ** 2
# ARCHITECTURE
LAYER_NORM_EPS = 1e-6
TRANSFORMER_LAYERS = 8
PROJECTION_DIM = 64
NUM_HEADS = 4
TRANSFORMER_UNITS = [
    PROJECTION_DIM * 2,
    PROJECTION_DIM,
]
MLP_HEAD_UNITS = [2048, 1024]

# %%
def plot_training_curves(history, title, model_name=''):
    if (model_name == 'teacher'):
      loss = np.array(history.history['loss'])
      val_loss = np.array(history.history['val_loss'])
      epochs = range(len(history.history['loss']))
    else:
      loss = np.array(history.history['student_loss'])
      val_loss = np.array(history.history['val_student_loss'])
      epochs = range(len(history.history['student_loss']))
    accuracy = np.array(history.history['accuracy'])
    val_accuracy = np.array(history.history['val_accuracy'])

    plt.style.use('fivethirtyeight')
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 4))
    fig.patch.set_facecolor('xkcd:white')

    # Plot loss
    ax1.plot(epochs, loss, label='training_loss', marker='.', )
    ax1.plot(epochs, val_loss, label='val_loss', marker='.', )
    ax1.fill_between(epochs, loss, val_loss, where=(loss > val_loss), color='C0', alpha=0.3, interpolate=True)
    ax1.fill_between(epochs, loss, val_loss, where=(loss < val_loss), color='C1', alpha=0.3, interpolate=True)
    ax1.set_title('Loss: '+title, fontsize=16)
    ax1.set_xlabel('Epochs', fontsize=14)
    ax1.legend()

    # Plot accuracy
    ax2.set_ylim(ymin=0, ymax=1.1)
    ax2.plot(epochs, accuracy, label='training_accuracy', marker='.')
    ax2.plot(epochs, val_accuracy, label='val_accuracy', marker='.')
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy > val_accuracy), color='C0', alpha=0.3, interpolate=True)
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy < val_accuracy), color='C1', alpha=0.3, interpolate=True)
    ax2.set_title('Accuracy: '+title, fontsize=16)
    ax2.set_xlabel('Epochs', fontsize=14)
    ax2.legend()

# %%
def visualize_dataset(dataset, title):
  plt.figure(figsize=(10, 10)).suptitle(title, fontsize=18)
  for images, labels in iter(dataset.take(9)):
    for i in range(9):
      ax = plt.subplot(3, 3, i + 1)
      img = tf.image.rgb_to_grayscale(images[i])
      plt.imshow(img, cmap='bone')
      ax.grid()
      plt.axis("off")

# %% [markdown]
# # Construct Distiller() class

# %%
class Distiller(keras.Model):
    def __init__(self, student, teacher):
        super().__init__()
        self.teacher = teacher
        self.student = student
    def compile(
        self,
        optimizer,
        metrics,
        student_loss_fn,
        distillation_loss_fn,
        alpha=0.1,
        temperature=3,
    ):
        """ Configure the distiller.
        Args:
            optimizer: Keras optimizer for the student weights
            metrics: Keras metrics for evaluation
            student_loss_fn: Loss function of difference between student
                predictions and ground-truth
            distillation_loss_fn: Loss function of difference between soft
                student predictions and soft teacher predictions
            alpha: weight to student_loss_fn and 1-alpha to distillation_loss_fn
            temperature: Temperature for softening probability distributions.
                Larger temperature gives softer distributions.
        """
        super().compile(optimizer=optimizer, metrics=metrics)
        self.student_loss_fn = student_loss_fn
        self.distillation_loss_fn = distillation_loss_fn
        self.alpha = alpha
        self.temperature = temperature

    def train_step(self, data):
        # Unpack data
        #x, y = data
        x = data[:][0] # get the 0th column of all rows
        y = data[:][1] # get the 1st column of all rows
        # Forward pass of teacher
        teacher_predictions = self.teacher(x, training=False)
        with tf.GradientTape() as tape:
            # Forward pass of student
            student_predictions = self.student(x, training=True)
            # Compute losses
            student_loss = self.student_loss_fn(y, student_predictions)
            # Compute scaled distillation loss from https://arxiv.org/abs/1503.02531
            # The magnitudes of the gradients produced by the soft targets scale
            # as 1/T^2, multiply them by T^2 when using both hard and soft targets.
            distillation_loss = (
                self.distillation_loss_fn(
                    tf.nn.softmax(teacher_predictions / self.temperature, axis=1),
                    tf.nn.softmax(student_predictions / self.temperature, axis=1),
                )
                * self.temperature**2
            )
            loss = self.alpha * student_loss + (1 - self.alpha) * distillation_loss
        # Compute gradients
        trainable_vars = self.student.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        # Update the metrics configured in `compile()`.
        self.compiled_metrics.update_state(y, student_predictions)
        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update(
            {"student_loss": student_loss, "distillation_loss": distillation_loss}
        )
        return results

    def test_step(self, data):
        # Unpack the data
        #x, y = data
        x = data[:][0] # get the 0th column of all rows
        y = data[:][1] # get the 1st column of all rows
        # Compute predictions
        y_prediction = self.student(x, training=False)
        # Calculate the loss
        student_loss = self.student_loss_fn(y, y_prediction)
        # Update the metrics.
        self.compiled_metrics.update_state(y, y_prediction)
        # Return a dict of performance
        results = {m.name: m.result() for m in self.metrics}
        results.update({"student_loss": student_loss})
        return results

# %% [markdown]
# #run_experiment module

# %%
from keras.src.callbacks import LearningRateScheduler
def run_experiment(training_dataset, validation_dataset, model, model_name=''):
    # Create LAMB optimizer with weight decay.
    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )

    # Compile the model.
    if(model_name == 'teacher'):
      model.compile(
          optimizer=optimizer,
          loss=keras.losses.CategoricalCrossentropy(from_logits=True),
          metrics=[
              keras.metrics.CategoricalAccuracy(name="accuracy"),
              keras.metrics.TopKCategoricalAccuracy(5, name="top5-acc"),
              keras.metrics.MeanSquaredError(name='Brier score'),
              keras.metrics.AUC(name='auc'),
          ],
      )
      # Create a learning rate scheduler callback.
      reduce_lr = keras.callbacks.ReduceLROnPlateau(
          monitor="val_loss", factor=0.2, patience=3
      )
      # Create an early stopping callback.
      early_stopping = tf.keras.callbacks.EarlyStopping(
          monitor="val_loss", patience=15, restore_best_weights=True
      )
    else:
      distiller.compile(
          optimizer=keras.optimizers.Adam(),
          metrics=[
              keras.metrics.CategoricalAccuracy(name="accuracy"),
              keras.metrics.TopKCategoricalAccuracy(5, name="top5-acc"),
              keras.metrics.MeanSquaredError(name='Brier score'),
              keras.metrics.AUC(name='auc'),
          ],
          student_loss_fn=keras.losses.CategoricalCrossentropy(from_logits=True),
          distillation_loss_fn=keras.losses.KLDivergence(),
          alpha=0.1,
          temperature=10,
      )
      # Create a learning rate scheduler callback.
      reduce_lr = keras.callbacks.ReduceLROnPlateau(
          monitor="student_loss", factor=0.2, patience=3
      )
      # Create an early stopping callback.
      early_stopping = tf.keras.callbacks.EarlyStopping(
          monitor="student_loss", patience=15, restore_best_weights=True
      )

    # Fit the model.
    history = model.fit(
        training_dataset,
        validation_data = validation_dataset,
        batch_size=batch_size,
        epochs=num_epochs,
        class_weight=class_weights_dict,
        callbacks=[early_stopping, reduce_lr],
    )
    # Return history to plot learning curves.
    return history

# %% [markdown]
# # 🔴 Transformer

# %%
class ShiftedPatchTokenization(layers.Layer):
    def __init__(
        self,
        image_size=IMG_SIZE,
        patch_size=PATCH_SIZE,
        num_patches=NUM_PATCHES,
        projection_dim=PROJECTION_DIM,
        vanilla=False,
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.vanilla = vanilla  # Flag to swtich to vanilla patch extractor
        self.image_size = image_size
        self.patch_size = patch_size
        self.half_patch = patch_size // 2
        self.flatten_patches = layers.Reshape((num_patches, -1))
        self.projection = layers.Dense(units=projection_dim)
        self.layer_norm = layers.LayerNormalization(epsilon=LAYER_NORM_EPS)

    def crop_shift_pad(self, images, mode):
        # Build the diagonally shifted images
        if mode == "left-up":
            crop_height = self.half_patch
            crop_width = self.half_patch
            shift_height = 0
            shift_width = 0
        elif mode == "left-down":
            crop_height = 0
            crop_width = self.half_patch
            shift_height = self.half_patch
            shift_width = 0
        elif mode == "right-up":
            crop_height = self.half_patch
            crop_width = 0
            shift_height = 0
            shift_width = self.half_patch
        else:
            crop_height = 0
            crop_width = 0
            shift_height = self.half_patch
            shift_width = self.half_patch

        # Crop the shifted images and pad them
        crop = tf.image.crop_to_bounding_box(
            images,
            offset_height=crop_height,
            offset_width=crop_width,
            target_height=self.image_size - self.half_patch,
            target_width=self.image_size - self.half_patch,
        )
        shift_pad = tf.image.pad_to_bounding_box(
            crop,
            offset_height=shift_height,
            offset_width=shift_width,
            target_height=self.image_size,
            target_width=self.image_size,
        )
        return shift_pad

    def call(self, images):
        if not self.vanilla:
            # Concat the shifted images with the original image
            images = tf.concat(
                [
                    images,
                    self.crop_shift_pad(images, mode="left-up"),
                    self.crop_shift_pad(images, mode="left-down"),
                    self.crop_shift_pad(images, mode="right-up"),
                    self.crop_shift_pad(images, mode="right-down"),
                ],
                axis=-1,
            )
        # Patchify the images and flatten it
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        flat_patches = self.flatten_patches(patches)
        if not self.vanilla:
            # Layer normalize the flat patches and linearly project it
            tokens = self.layer_norm(flat_patches)
            tokens = self.projection(tokens)
        else:
            # Linearly project the flat patches
            tokens = self.projection(flat_patches)
        return (tokens, patches)

# %%
class PatchEncoder(layers.Layer):
    def __init__(
        self, num_patches=NUM_PATCHES, projection_dim=PROJECTION_DIM, **kwargs
    ):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )
        self.positions = tf.range(start=0, limit=self.num_patches, delta=1)

    def call(self, encoded_patches):
        encoded_positions = self.position_embedding(self.positions)
        encoded_patches = encoded_patches + encoded_positions
        return encoded_patches

# %%
class MultiHeadAttentionLSA(tf.keras.layers.MultiHeadAttention):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        # The trainable temperature term. The initial value is
        # the square root of the key dimension.
        self.tau = tf.Variable(math.sqrt(float(self._key_dim)), trainable=True)

    def _compute_attention(self, query, key, value, attention_mask=None, training=None):
        query = tf.multiply(query, 1.0 / self.tau)
        attention_scores = tf.einsum(self._dot_product_equation, key, query)
        attention_scores = self._masked_softmax(attention_scores, attention_mask)
        attention_scores_dropout = self._dropout_layer(
            attention_scores, training=training
        )
        attention_output = tf.einsum(
            self._combine_equation, attention_scores_dropout, value
        )
        return attention_output, attention_scores

# %%
class BaseAttention(tf.keras.layers.Layer):
    """
    Base class for all attention layers. It contains the common functionality of all attention layers.
    This layer contains a MultiHeadAttention layer, a LayerNormalization layer and an Add layer.
    It is used as a base class for the GlobalSelfAttention, CausalSelfAttention and CrossAttention layers.
    And it is not intended to be used directly.
    Attributes:
        mha (tf.keras.layers.MultiHeadAttention): The MultiHeadAttention layer.
        layernorm (tf.keras.layers.LayerNormalization): The LayerNormalization layer.
        add (tf.keras.layers.Add): The Add layer.
    """
    def __init__(self, **kwargs: dict):
        """ Constructor of the BaseAttention layer.
        Args:
            **kwargs: Additional keyword arguments that are passed to the MultiHeadAttention layer, e. g.
                        num_heads (number of heads), key_dim (dimensionality of the key space), etc.
        """
        super().__init__()
        self.mha = tf.keras.layers.MultiHeadAttention(**kwargs)
        self.layernorm = tf.keras.layers.LayerNormalization()
        self.add = tf.keras.layers.Add()

class CrossAttention(BaseAttention):
    """
    A class that implements the cross-attention layer by inheriting from the BaseAttention class.
    This layer is used to process two different sequences and attends to the context sequence while processing the query sequence.
    Attributes:
        mha (tf.keras.layers.MultiHeadAttention): The MultiHeadAttention layer.
        layernorm (tf.keras.layers.LayerNormalization): The LayerNormalization layer.
        add (tf.keras.layers.Add): The Add layer.
    """
    def call(self, x: tf.Tensor, context: tf.Tensor) -> tf.Tensor:
        """
        The call function that performs the cross-attention operation.
        Args:
            x (tf.Tensor): The query (expected Transformer results) sequence of shape (batch_size, seq_length, d_model).
            context (tf.Tensor): The context (inputs to the Encoder layer) sequence of shape (batch_size, seq_length, d_model).
        Returns:
            tf.Tensor: The output sequence of shape (batch_size, seq_length, d_model).
        """
        attn_output, attn_scores = self.mha(query=x, key=context, value=context, return_attention_scores=True)
        # Cache the attention scores for plotting later.
        self.last_attn_scores = attn_scores
        x = self.add([x, attn_output])
        x = self.layernorm(x)
        return x

class GlobalSelfAttention(BaseAttention):
    """
    A class that implements the global self-attention layer by inheriting from the BaseAttention class.
    This layer is used to process a single sequence and attends to all the tokens in the sequence.
    Attributes:
        mha (tf.keras.layers.MultiHeadAttention): The MultiHeadAttention layer.
        layernorm (tf.keras.layers.LayerNormalization): The LayerNormalization layer.
        add (tf.keras.layers.Add): The Add layer.
    """
    def call(self, x: tf.Tensor) -> tf.Tensor:
        """
        The call function that performs the global self-attention operation.
        Args:
            x (tf.Tensor): The input sequence of shape (batch_size, seq_length, d_model).
        Returns:
            tf.Tensor: The output sequence of shape (batch_size, seq_length, d_model).
        """
        attn_output = self.mha(query=x, value=x, key=x)
        x = self.add([x, attn_output])
        x = self.layernorm(x)
        return x

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
# Build the diagonal attention mask
diag_attn_mask = 1 - tf.eye(NUM_PATCHES)
diag_attn_mask = tf.cast([diag_attn_mask], dtype=tf.int8)

# %%
def create_transfomer(vanilla=False):
    inputs = layers.Input(shape=input_shape)

    # Create patches.
    (tokens, _) = ShiftedPatchTokenization(vanilla=vanilla)(inputs)
    # Encode patches.
    encoded_patches = PatchEncoder()(tokens)

    # Create multiple layers of the Transformer block.
    for _ in range(TRANSFORMER_LAYERS):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # slef locality attention layer
        attention_output = MultiHeadAttentionLSA(
            num_heads=NUM_HEADS, key_dim=PROJECTION_DIM, dropout=0.1
        )(x1, x1, attention_mask=diag_attn_mask)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=TRANSFORMER_UNITS, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches_1 = layers.Add()([x3, x2])
        #####################################################################
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches_1)
        # Global attention layer
        attention_output = GlobalSelfAttention(
            num_heads=NUM_HEADS, key_dim=PROJECTION_DIM
        )(x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches_1])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=TRANSFORMER_UNITS, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches_2 = layers.Add()([x3, x2])
        #####################################################################
        # Cross attention layer
        attention_output = CrossAttention(
            num_heads=NUM_HEADS, key_dim=PROJECTION_DIM
        )(encoded_patches_1, encoded_patches_2)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches_2])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=TRANSFORMER_UNITS, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.5)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=MLP_HEAD_UNITS, dropout_rate=0.5)
    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES)(features)

    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %% [markdown]
# ---

# %% [markdown]
# # 📂 Load BTDS-17C

# %%
##################
NUM_CLASSES = 17
##################
path = '/content/drive/MyDrive/Multiclass_Brain_Tumor_MRI/MRI_17Classes/'
# train data
train_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='int',
    batch_size=32,
    image_size=(IMG_SIZE,IMG_SIZE),
    color_mode='rgb',
    #shuffle=True,
    seed=128,
    validation_split=0.2,
    subset='training',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# validation data
val_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='int',
    batch_size=32,
    image_size=(IMG_SIZE,IMG_SIZE),
    color_mode='rgb',
    #shuffle=True,
    seed=128,
    validation_split=0.2,
    subset='validation',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
#Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 4415 files belonging to 17 classes.
# Using 3532 files for training.
# Found 4415 files belonging to 17 classes.
# Using 883 files for validation.

# %% [markdown]
# ## ◼ Class Weighting

# %%
#label_mode='categorical',
train_ds_cat = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(IMG_SIZE,IMG_SIZE),
)
class_names = train_ds_cat.class_names
num_images_per_class = []
for label in class_names:
    dir_name = path + label
    num_images_per_class.append(len([name for name in os.listdir(dir_name)]))
# y_train=list of train labels wrt to given directory format
y_train=[]
for i in range(0, len(num_images_per_class)):
    y_train+=[i]*num_images_per_class[i]
classes = list()
for i in range(NUM_CLASSES): classes.append(i)
class_weights=compute_class_weight(class_weight="balanced",classes=classes, y=np.asarray(y_train))
class_weights_dict = {}
for i in range(len(class_weights)):
   class_weights_dict[i] = class_weights[i]
class_weights_dict
# Out:
# Found 4415 files belonging to 17 classes.
# {0: 0.5700371651928745,
#  1: 0.5110294117647058,
#  2: 0.7562053723223393,
#  3: 0.7583972719522591,
#  4: 0.41863529411764705,
#  5: 0.7952798140532809,
#  6: 0.9619377162629758,
#  7: 0.8991307863351526,
#  8: 1.5482074486599373,
#  9: 1.0024791525805725,
#  10: 2.3361344537815127,
#  11: 1.721362229102167,
#  12: 5.450980392156863,
#  13: 4.590299277605779,
#  14: 1.7101114955786236,
#  15: 1.348696179502729,
#  16: 2.127211860353898}

# %% [markdown]
# # 🅰 Data augmentation
#
# In the original paper, the authors use AutoAugment to induce stronger regularization. For this example, we will be using the standard geometric augmentations like random cropping and flipping. https://arxiv.org/abs/1805.09501

# %%
def to_dict(image, label):
    image = tf.cast(image, tf.float32)
    label = tf.one_hot(label, NUM_CLASSES)
    return {"images": image, "labels": label}

def preprocess_for_model(inputs):
    images, labels = inputs["images"], inputs["labels"]
    images = tf.cast(images, tf.float32)
    return images, labels

augmix = keras_cv.layers.AugMix([0, 255])
mixup = keras_cv.layers.MixUp()
cutmix = keras_cv.layers.CutMix(alpha=0.02)

#No augmentation
train_ds_v = train_ds.map(to_dict)
train_ds_v = train_ds_v.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
train_ds_v = train_ds_v.prefetch(AUTOTUNE)
val_ds_v = val_ds.map(to_dict)
val_ds_v = val_ds_v.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
val_ds_v = val_ds_v.prefetch(AUTOTUNE) #Use this for fit

# %%
def aug_pipeline1(samples):
    samples = augmix(samples, training=True)
    return samples
def aug_pipeline2(samples):
    samples = mixup(samples, training=True)
    return samples
def aug_pipeline3(samples):
    samples = cutmix(samples, training=True)
    return samples
def aug_pipeline(samples):
    samples = augmix(samples, training=True)
    samples = mixup(samples, training=True)
    samples = cutmix(samples, training=True)
    return samples
#AugMix
augmix_ds = train_ds.shuffle(1000).map(to_dict)
augmix_ds = augmix_ds.map(aug_pipeline1)
augmix_ds = augmix_ds.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
augmix_ds = augmix_ds.prefetch(AUTOTUNE) #Use this for fit
#MixUp
mixup_ds = train_ds.shuffle(1000).map(to_dict)
mixup_ds = mixup_ds.map(aug_pipeline2)
mixup_ds = mixup_ds.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
mixup_ds = mixup_ds.prefetch(AUTOTUNE) #Use this for fit
#CutMix
cutmix_ds = train_ds.shuffle(1000).map(to_dict)
cutmix_ds = cutmix_ds.map(aug_pipeline3)
cutmix_ds = cutmix_ds.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
cutmix_ds = cutmix_ds.prefetch(AUTOTUNE) #Use this for fit
#AugPip
augpip_ds = train_ds.shuffle(1000).map(to_dict)
augpip_ds = augpip_ds.map(aug_pipeline)
augpip_ds = augpip_ds.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
augpip_ds = augpip_ds.prefetch(AUTOTUNE) #Use this for fit

# %% [markdown]
# ## Create student and teacher models

# %%
TRANSFORMER_LAYERS = 4
NUM_HEADS = 2
transformer_teacher = create_transfomer()
#####################################################
TRANSFORMER_LAYERS = 2
NUM_HEADS = 2
transformer_student = create_transfomer()

# %% [markdown]
# ### ▶ No Aug

# %%
history = run_experiment(train_ds_v, val_ds_v, transformer_teacher, model_name='teacher')
# Out:
# Epoch 1/100
# 111/111 [==============================] - 327s 3s/step - loss: 7.8751 - accuracy: 0.2409 - top5-acc: 0.5796 - Brier score: 63.9533 - auc: 0.6472 - val_loss: 1.9124 - val_accuracy: 0.4371 - val_top5-acc: 0.7735 - val_Brier score: 7.1275 - val_auc: 0.7681 - lr: 0.0010
# Epoch 2/100
# 111/111 [==============================] - 31s 274ms/step - loss: 2.2908 - accuracy: 0.4485 - top5-acc: 0.8083 - Brier score: 28.7248 - auc: 0.7520 - val_loss: 1.5554 - val_accuracy: 0.5323 - val_top5-acc: 0.8573 - val_Brier score: 7.7563 - val_auc: 0.8024 - lr: 0.0010
# Epoch 3/100
# 111/111 [==============================] - 31s 274ms/step - loss: 1.5521 - accuracy: 0.5756 - top5-acc: 0.8805 - Brier score: 29.9704 - auc: 0.7809 - val_loss: 1.2205 - val_accuracy: 0.6546 - val_top5-acc: 0.9320 - val_Brier score: 8.4095 - val_auc: 0.8602 - lr: 0.0010
# Epoch 4/100
# 111/111 [==============================] - 31s 275ms/step - loss: 1.0151 - accuracy: 0.6874 - top5-acc: 0.9411 - Brier score: 46.0579 - auc: 0.7958 - val_loss: 1.1810 - val_accuracy: 0.6784 - val_top5-acc: 0.9377 - val_Brier score: 15.7598 - val_auc: 0.8235 - lr: 0.0010
# Epoch 5/100
# 111/111 [==============================] - 31s 274ms/step - loss: 0.6991 - accuracy: 0.7540 - top5-acc: 0.9677 - Brier score: 62.8529 - auc: 0.7914 - val_loss: 0.9331 - val_accuracy: 0.7180 - val_top5-acc: 0.9468 - val_Brier score: 15.6839 - val_auc: 0.8330 - lr: 0.0010
# Epoch 6/100
# 111/111 [==============================] - 31s 275ms/step - loss: 0.6767 - accuracy: 0.8046 - top5-acc: 0.9762 - Brier score: 72.4307 - auc: 0.8064 - val_loss: 0.8697 - val_accuracy: 0.7327 - val_top5-acc: 0.9558 - val_Brier score: 15.1624 - val_auc: 0.8511 - lr: 0.0010
# Epoch 7/100
# Epoch 35/100
# 111/111 [==============================] - 30s 270ms/step - loss: 0.0289 - accuracy: 0.9949 - top5-acc: 1.0000 - Brier score: 25.6805 - auc: 0.8791 - val_loss: 0.6677 - val_accuracy: 0.8086 - val_top5-acc: 0.9706 - val_Brier score: 6.5273 - val_auc: 0.9101 - lr: 1.6000e-06
# Epoch 36/100
# 111/111 [==============================] - 30s 271ms/step - loss: 0.0302 - accuracy: 0.9949 - top5-acc: 1.0000 - Brier score: 23.3630 - auc: 0.8802 - val_loss: 0.6741 - val_accuracy: 0.8097 - val_top5-acc: 0.9706 - val_Brier score: 5.9488 - val_auc: 0.9125 - lr: 3.2000e-07
# Epoch 37/100
# 111/111 [==============================] - 30s 270ms/step - loss: 0.0341 - accuracy: 0.9941 - top5-acc: 1.0000 - Brier score: 21.8290 - auc: 0.8841 - val_loss: 0.6819 - val_accuracy: 0.8086 - val_top5-acc: 0.9717 - val_Brier score: 5.4208 - val_auc: 0.9151 - lr: 3.2000e-07
# Epoch 38/100
# 111/111 [==============================] - 31s 276ms/step - loss: 0.0333 - accuracy: 0.9949 - top5-acc: 1.0000 - Brier score: 19.4399 - auc: 0.8857 - val_loss: 0.6911 - val_accuracy: 0.8097 - val_top5-acc: 0.9717 - val_Brier score: 4.9396 - val_auc: 0.9172 - lr: 3.2000e-07

# %%
plot_training_curves(history, 'Teatcher (Tripartite Transformer- NoAug)', model_name='teacher')

# %%
distiller = Distiller(student=transformer_student, teacher=transformer_teacher)
history = run_experiment(train_ds_v, val_ds_v, distiller, model_name='distiller')
# Out:
# Epoch 1/100
# 111/111 [==============================] - 52s 254ms/step - accuracy: 0.3012 - top5-acc: 0.6843 - Brier score: 38.1623 - auc: 0.7009 - student_loss: 4.9518 - distillation_loss: 32.7065 - val_accuracy: 0.5549 - val_top5-acc: 0.8879 - val_Brier score: 10.5666 - val_auc: 0.8360 - val_student_loss: 1.2253 - lr: 0.0010
# Epoch 2/100
# 111/111 [==============================] - 26s 236ms/step - accuracy: 0.5156 - top5-acc: 0.8635 - Brier score: 39.0830 - auc: 0.7986 - student_loss: 2.0731 - distillation_loss: 18.4836 - val_accuracy: 0.6263 - val_top5-acc: 0.9060 - val_Brier score: 12.9058 - val_auc: 0.8585 - val_student_loss: 0.8448 - lr: 0.0010
# Epoch 3/100
# 111/111 [==============================] - 26s 236ms/step - accuracy: 0.6518 - top5-acc: 0.9343 - Brier score: 42.3694 - auc: 0.8339 - student_loss: 1.3055 - distillation_loss: 13.3764 - val_accuracy: 0.6818 - val_top5-acc: 0.9320 - val_Brier score: 11.1258 - val_auc: 0.8839 - val_student_loss: 1.1296 - lr: 0.0010
# Epoch 4/100
# 111/111 [==============================] - 25s 228ms/step - accuracy: 0.7041 - top5-acc: 0.9490 - Brier score: 38.2572 - auc: 0.8471 - student_loss: 1.0678 - distillation_loss: 12.5400 - val_accuracy: 0.6761 - val_top5-acc: 0.9377 - val_Brier score: 12.9443 - val_auc: 0.8810 - val_student_loss: 1.6077 - lr: 0.0010
# 111/111 [==============================] - 26s 229ms/step - accuracy: 0.9765 - top5-acc: 0.9989 - Brier score: 35.1036 - auc: 0.8680 - student_loss: 0.0739 - distillation_loss: 3.4943 - val_accuracy: 0.8086 - val_top5-acc: 0.9785 - val_Brier score: 12.3079 - val_auc: 0.8881 - val_student_loss: 0.7690 - lr: 5.1200e-10
# Epoch 47/100
# 111/111 [==============================] - 26s 229ms/step - accuracy: 0.9779 - top5-acc: 0.9997 - Brier score: 34.3742 - auc: 0.8708 - student_loss: 0.0721 - distillation_loss: 3.6090 - val_accuracy: 0.8086 - val_top5-acc: 0.9785 - val_Brier score: 12.3079 - val_auc: 0.8881 - val_student_loss: 0.1293 - lr: 5.1200e-10
# Epoch 48/100
# 111/111 [==============================] - 26s 228ms/step - accuracy: 0.9745 - top5-acc: 0.9994 - Brier score: 33.7205 - auc: 0.8693 - student_loss: 0.0799 - distillation_loss: 3.5430 - val_accuracy: 0.8086 - val_top5-acc: 0.9785 - val_Brier score: 12.3079 - val_auc: 0.8881 - val_student_loss: 0.4481 - lr: 5.1200e-10
# Epoch 49/100
# 111/111 [==============================] - 26s 229ms/step - accuracy: 0.9793 - top5-acc: 0.9989 - Brier score: 34.5900 - auc: 0.8687 - student_loss: 0.0729 - distillation_loss: 3.5360 - val_accuracy: 0.8086 - val_top5-acc: 0.9785 - val_Brier score: 12.3079 - val_auc: 0.8881 - val_student_loss: 0.5645 - lr: 1.0240e-10
# Epoch 50/100
# 111/111 [==============================] - 26s 229ms/step - accuracy: 0.9810 - top5-acc: 0.9992 - Brier score: 34.4070 - auc: 0.8690 - student_loss: 0.0703 - distillation_loss: 3.7048 - val_accuracy: 0.8086 - val_top5-acc: 0.9785 - val_Brier score: 12.3079 - val_auc: 0.8881 - val_student_loss: 0.4858 - lr: 1.0240e-10
# Epoch 51/100
# 111/111 [==============================] - 27s 240ms/step - accuracy: 0.9773 - top5-acc: 0.9997 - Brier score: 34.1282 - auc: 0.8689 - student_loss: 0.0758 - distillation_loss: 3.5391 - val_accuracy: 0.8086 - val_top5-acc: 0.9785 - val_Brier score: 12.3079 - val_auc: 0.8881 - val_student_loss: 0.5637 - lr: 1.0240e-10

# %%
plot_training_curves(history, 'Student (Tripartite Transformer- NoAug)', model_name='student')

# %% [markdown]
# ### ▶ AugMix

# %%
history = run_experiment(augmix_ds, val_ds_v, transformer_teacher, model_name='teacher')
# Out:
# Epoch 1/100
# 111/111 [==============================] - 95s 652ms/step - loss: 7.8052 - accuracy: 0.1659 - top5-acc: 0.4915 - Brier score: 43.4158 - auc: 0.6121 - val_loss: 2.0581 - val_accuracy: 0.3862 - val_top5-acc: 0.7475 - val_Brier score: 2.9171 - val_auc: 0.7833 - lr: 0.0010
# Epoch 2/100
# 111/111 [==============================] - 76s 663ms/step - loss: 2.7546 - accuracy: 0.2857 - top5-acc: 0.6552 - Brier score: 10.8320 - auc: 0.7050 - val_loss: 2.1070 - val_accuracy: 0.3556 - val_top5-acc: 0.7101 - val_Brier score: 3.0957 - val_auc: 0.7648 - lr: 0.0010
# Epoch 3/100
# Epoch 68/100
# 111/111 [==============================] - 75s 657ms/step - loss: 0.4109 - accuracy: 0.9105 - top5-acc: 0.9779 - Brier score: 4.0727 - auc: 0.9486 - val_loss: 0.7517 - val_accuracy: 0.7984 - val_top5-acc: 0.9717 - val_Brier score: 2.5645 - val_auc: 0.9494 - lr: 1.2800e-08
# Epoch 69/100
# 111/111 [==============================] - 76s 661ms/step - loss: 0.4254 - accuracy: 0.9148 - top5-acc: 0.9805 - Brier score: 3.6789 - auc: 0.9512 - val_loss: 0.7707 - val_accuracy: 0.7973 - val_top5-acc: 0.9706 - val_Brier score: 2.3326 - val_auc: 0.9506 - lr: 1.2800e-08

# %%
plot_training_curves(history, 'Teatcher (Tripartite Transformer- AugMix)', model_name='teacher')

# %%
distiller = Distiller(student=transformer_student, teacher=transformer_teacher)
history = run_experiment(augmix_ds, val_ds_v, distiller, model_name='distiller')
# Out:
# Epoch 1/100
# 111/111 [==============================] - 93s 603ms/step - accuracy: 0.2126 - top5-acc: 0.5742 - Brier score: 14.9098 - auc: 0.6469 - student_loss: 3.8863 - distillation_loss: 10.3388 - val_accuracy: 0.3907 - val_top5-acc: 0.7724 - val_Brier score: 1.6901 - val_auc: 0.7951 - val_student_loss: 1.8575 - lr: 0.0010
# Epoch 2/100
# 111/111 [==============================] - 75s 651ms/step - accuracy: 0.3177 - top5-acc: 0.6985 - Brier score: 6.7583 - auc: 0.7341 - student_loss: 2.2856 - distillation_loss: 6.0549 - val_accuracy: 0.4519 - val_top5-acc: 0.8562 - val_Brier score: 3.4333 - val_auc: 0.8446 - val_student_loss: 1.7579 - lr: 0.0010
# Epoch 3/100
# 111/111 [==============================] - 74s 645ms/step - accuracy: 0.3751 - top5-acc: 0.7387 - Brier score: 7.0982 - auc: 0.7535 - student_loss: 2.0844 - distillation_loss: 5.3994 - val_accuracy: 0.4960 - val_top5-acc: 0.8562 - val_Brier score: 3.0115 - val_auc: 0.8332 - val_student_loss: 2.0192 - lr: 0.0010
# Epoch 4/100
# 111/111 [==============================] - 74s 647ms/step - accuracy: 0.3941 - top5-acc: 0.7837 - Brier score: 6.7892 - auc: 0.7755 - student_loss: 1.9458 - distillation_loss: 5.1227 - val_accuracy: 0.4779 - val_top5-acc: 0.8845 - val_Brier score: 4.4839 - val_auc: 0.8497 - val_student_loss: 1.5841 - lr: 0.0010
# Epoch 5/100
# 111/111 [==============================] - 74s 642ms/step - accuracy: 0.4224 - top5-acc: 0.8015 - Brier score: 7.7527 - auc: 0.7665 - student_loss: 1.8810 - distillation_loss: 5.1484 - val_accuracy: 0.5606 - val_top5-acc: 0.9060 - val_Brier score: 3.8529 - val_auc: 0.8408 - val_student_loss: 0.9575 - lr: 0.0010
# Epoch 6/100
# 111/111 [==============================] - 73s 638ms/step - accuracy: 0.4765 - top5-acc: 0.8364 - Brier score: 8.3134 - auc: 0.7881 - student_loss: 1.6776 - distillation_loss: 4.3206 - val_accuracy: 0.5617 - val_top5-acc: 0.9151 - val_Brier score: 5.2495 - val_auc: 0.8478 - val_student_loss: 1.3461 - lr: 0.0010
# 111/111 [==============================] - 74s 649ms/step - accuracy: 0.7630 - top5-acc: 0.9522 - Brier score: 11.2143 - auc: 0.7608 - student_loss: 0.7684 - distillation_loss: 1.5542 - val_accuracy: 0.7508 - val_top5-acc: 0.9649 - val_Brier score: 9.0751 - val_auc: 0.7947 - val_student_loss: 0.7257 - lr: 5.1200e-10
# Epoch 49/100
# 111/111 [==============================] - 74s 641ms/step - accuracy: 0.7687 - top5-acc: 0.9547 - Brier score: 11.9422 - auc: 0.7582 - student_loss: 0.7296 - distillation_loss: 1.7166 - val_accuracy: 0.7508 - val_top5-acc: 0.9649 - val_Brier score: 9.0751 - val_auc: 0.7947 - val_student_loss: 1.0090 - lr: 5.1200e-10
# Epoch 50/100
# 111/111 [==============================] - 75s 656ms/step - accuracy: 0.7681 - top5-acc: 0.9516 - Brier score: 11.8082 - auc: 0.7601 - student_loss: 0.7483 - distillation_loss: 1.6650 - val_accuracy: 0.7508 - val_top5-acc: 0.9649 - val_Brier score: 9.0751 - val_auc: 0.7947 - val_student_loss: 0.3728 - lr: 5.1200e-10

# %%
plot_training_curves(history, 'Student (Tripartite Transformer- AugMix)', model_name='student')

# %% [markdown]
# ### ▶ CutMix

# %%
history = run_experiment(cutmix_ds, val_ds_v, transformer_teacher, model_name='teacher')
# Out:
# Epoch 1/100
# 111/111 [==============================] - 55s 297ms/step - loss: 7.7320 - accuracy: 0.1648 - top5-acc: 0.4977 - Brier score: 42.9489 - auc: 0.6052 - val_loss: 2.2762 - val_accuracy: 0.2978 - val_top5-acc: 0.6908 - val_Brier score: 1.6594 - val_auc: 0.7566 - lr: 0.0010
# Epoch 2/100
# 111/111 [==============================] - 32s 273ms/step - loss: 2.9334 - accuracy: 0.2206 - top5-acc: 0.5660 - Brier score: 6.0304 - auc: 0.6368 - val_loss: 2.1673 - val_accuracy: 0.3273 - val_top5-acc: 0.6852 - val_Brier score: 1.4472 - val_auc: 0.7617 - lr: 0.0010
# Epoch 3/100
# 111/111 [==============================] - 32s 273ms/step - loss: 2.4862 - accuracy: 0.2344 - top5-acc: 0.6311 - Brier score: 6.2330 - auc: 0.6724 - val_loss: 2.1288 - val_accuracy: 0.2933 - val_top5-acc: 0.7225 - val_Brier score: 1.9300 - val_auc: 0.7722 - lr: 0.0010
# Epoch 4/100
# 111/111 [==============================] - 32s 273ms/step - loss: 2.4251 - accuracy: 0.2602 - top5-acc: 0.6215 - Brier score: 6.0363 - auc: 0.6736 - val_loss: 1.9459 - val_accuracy: 0.4270 - val_top5-acc: 0.8335 - val_Brier score: 1.6348 - val_auc: 0.8313 - lr: 0.0010
# Epoch 5/100
# 111/111 [==============================] - 32s 273ms/step - loss: 2.1349 - accuracy: 0.2990 - top5-acc: 0.6911 - Brier score: 7.2695 - auc: 0.7086 - val_loss: 1.8668 - val_accuracy: 0.3986 - val_top5-acc: 0.8041 - val_Brier score: 3.1718 - val_auc: 0.8036 - lr: 0.0010
# Epoch 6/100
# 111/111 [==============================] - 32s 272ms/step - loss: 2.0907 - accuracy: 0.3219 - top5-acc: 0.7228 - Brier score: 9.9216 - auc: 0.7223 - val_loss: 1.6752 - val_accuracy: 0.4632 - val_top5-acc: 0.8641 - val_Brier score: 3.5622 - val_auc: 0.8415 - lr: 0.0010
100
# 111/111 [==============================] - 32s 269ms/step - loss: 0.5566 - accuracy: 0.8624 - top5-acc: 0.9759 - Brier score: 4.5812 - auc: 0.8967 - val_loss: 0.7147 - val_accuracy: 0.7961 - val_top5-acc: 0.9762 - val_Brier score: 2.2913 - val_auc: 0.9566 - lr: 1.6000e-06
# Epoch 46/100
# 111/111 [==============================] - 32s 268ms/step - loss: 0.5397 - accuracy: 0.8638 - top5-acc: 0.9796 - Brier score: 4.4038 - auc: 0.8998 - val_loss: 0.7254 - val_accuracy: 0.7950 - val_top5-acc: 0.9751 - val_Brier score: 2.1528 - val_auc: 0.9573 - lr: 1.6000e-06
# Epoch 47/100
# 111/111 [==============================] - 32s 269ms/step - loss: 0.5962 - accuracy: 0.8488 - top5-acc: 0.9737 - Brier score: 4.0933 - auc: 0.8999 - val_loss: 0.7389 - val_accuracy: 0.7939 - val_top5-acc: 0.9762 - val_Brier score: 2.0051 - val_auc: 0.9579 - lr: 3.2000e-07
# Epoch 48/100
# 111/111 [==============================] - 32s 269ms/step - loss: 0.5587 - accuracy: 0.8661 - top5-acc: 0.9799 - Brier score: 3.8437 - auc: 0.9043 - val_loss: 0.7530 - val_accuracy: 0.7950 - val_top5-acc: 0.9773 - val_Brier score: 1.8698 - val_auc: 0.9586 - lr: 3.2000e-07
# Epoch 49/100
# 111/111 [==============================] - 33s 274ms/step - loss: 0.6263 - accuracy: 0.8576 - top5-acc: 0.9742 - Brier score: 3.5178 - auc: 0.8957 - val_loss: 0.7682 - val_accuracy: 0.7939 - val_top5-acc: 0.9762 - val_Brier score: 1.7437 - val_auc: 0.9598 - lr: 3.2000e-07

# %%
plot_training_curves(history, 'Teatcher (Tripartite Transformer- CutMix)', model_name='teacher')

# %%
distiller = Distiller(student=transformer_student, teacher=transformer_teacher)
history = run_experiment(cutmix_ds, val_ds_v, distiller, model_name='distiller')
# Out:
# Epoch 1/100
# 111/111 [==============================] - 54s 254ms/step - accuracy: 0.1571 - top5-acc: 0.5227 - Brier score: 9.0757 - auc: 0.6245 - student_loss: 3.8472 - distillation_loss: 6.2707 - val_accuracy: 0.3511 - val_top5-acc: 0.7667 - val_Brier score: 0.4480 - val_auc: 0.8057 - val_student_loss: 2.3942 - lr: 0.0010
# Epoch 2/100
# 111/111 [==============================] - 27s 227ms/step - accuracy: 0.2520 - top5-acc: 0.6730 - Brier score: 2.5162 - auc: 0.7072 - student_loss: 2.3661 - distillation_loss: 2.9416 - val_accuracy: 0.4077 - val_top5-acc: 0.8403 - val_Brier score: 0.9548 - val_auc: 0.8420 - val_student_loss: 1.6745 - lr: 0.0010
# Epoch 3/100
# 111/111 [==============================] - 27s 227ms/step - accuracy: 0.3131 - top5-acc: 0.7548 - Brier score: 2.8950 - auc: 0.7401 - student_loss: 2.1589 - distillation_loss: 2.7239 - val_accuracy: 0.4994 - val_top5-acc: 0.8935 - val_Brier score: 1.2342 - val_auc: 0.8746 - val_student_loss: 2.0223 - lr: 0.0010
# Epoch 4/100
# 111/111 [==============================] - 28s 235ms/step - accuracy: 0.3834 - top5-acc: 0.7990 - Brier score: 3.0817 - auc: 0.7570 - student_loss: 1.9427 - distillation_loss: 2.4158 - val_accuracy: 0.5413 - val_top5-acc: 0.9128 - val_Brier score: 1.5413 - val_auc: 0.8758 - val_student_loss: 1.9425 - lr: 0.0010
# Epoch 5/100
# 111/111 [==============================] - 28s 235ms/step - accuracy: 0.4250 - top5-acc: 0.8080 - Brier score: 3.4399 - auc: 0.7571 - student_loss: 1.8562 - distillation_loss: 2.2572 - val_accuracy: 0.5753 - val_top5-acc: 0.9173 - val_Brier score: 1.7903 - val_auc: 0.8693 - val_student_loss: 1.0899 - lr: 0.0010
# Epoch 6/100
# 111/111 [==============================] - 27s 227ms/step - accuracy: 0
100
# 111/111 [==============================] - 27s 227ms/step - accuracy: 0.6979 - top5-acc: 0.9335 - Brier score: 4.6816 - auc: 0.7820 - student_loss: 1.0911 - distillation_loss: 1.1813 - val_accuracy: 0.7633 - val_top5-acc: 0.9672 - val_Brier score: 2.4224 - val_auc: 0.8604 - val_student_loss: 1.1065 - lr: 5.1200e-10
# Epoch 44/100
# 111/111 [==============================] - 27s 227ms/step - accuracy: 0.6962 - top5-acc: 0.9275 - Brier score: 4.9384 - auc: 0.7758 - student_loss: 1.1148 - distillation_loss: 1.1595 - val_accuracy: 0.7633 - val_top5-acc: 0.9672 - val_Brier score: 2.4224 - val_auc: 0.8604 - val_student_loss: 0.5418 - lr: 5.1200e-10
# Epoch 45/100
# 111/111 [==============================] - 29s 238ms/step - accuracy: 0.6897 - top5-acc: 0.9434 - Brier score: 4.7745 - auc: 0.7815 - student_loss: 1.1027 - distillation_loss: 1.1968 - val_accuracy: 0.7633 - val_top5-acc: 0.9672 - val_Brier score: 2.4224 - val_auc: 0.8604 - val_student_loss: 0.8302 - lr: 5.1200e-10

# %%
plot_training_curves(history, 'Student (Tripartite Transformer- CutMix)', model_name='student')

# %% [markdown]
# ### ▶ MixUp

# %%
history = run_experiment(mixup_ds, val_ds_v, transformer_teacher, model_name='teacher')
# Out:
# Epoch 1/100
# 111/111 [==============================] - 55s 298ms/step - loss: 7.1426 - accuracy: 0.1770 - top5-acc: 0.5309 - Brier score: 46.1332 - auc: 0.5921 - val_loss: 2.0949 - val_accuracy: 0.3692 - val_top5-acc: 0.7384 - val_Brier score: 1.3506 - val_auc: 0.7835 - lr: 0.0010
# Epoch 2/100
# 111/111 [==============================] - 32s 274ms/step - loss: 2.6909 - accuracy: 0.2837 - top5-acc: 0.6537 - Brier score: 6.9372 - auc: 0.6480 - val_loss: 1.9576 - val_accuracy: 0.4020 - val_top5-acc: 0.7973 - val_Brier score: 1.0843 - val_auc: 0.8268 - lr: 0.0010
# Epoch 3/100
# 111/111 [==============================] - 32s 273ms/step - loss: 2.2212 - accuracy: 0.3644 - top5-acc: 0.7531 - Brier score: 7.5161 - auc: 0.6785 - val_loss: 1.6586 - val_accuracy: 0.5130 - val_top5-acc: 0.8675 - val_Brier score: 1.9916 - val_auc: 0.8583 - lr: 0.0010
# Epoch 4/100
# 111/111 [==============================] - 32s 273ms/step - loss: 1.8909 - accuracy: 0.4148 - top5-acc: 0.8120 - Brier score: 7.3525 - auc: 0.7092 - val_loss: 1.5635 - val_accuracy: 0.5289 - val_top5-acc: 0.8811 - val_Brier score: 2.2695 - val_auc: 0.8610 - lr: 0.0010
# Epoch 5/100
# 111/111 [==============================] - 32s 273ms/step - loss: 1.7652 - accuracy: 0.5011 - top5-acc: 0.8525 - Brier score: 8.1083 - auc: 0.7153 - val_loss: 1.5561 - val_accuracy: 0.5606 - val_top5-acc: 0.8890 - val_Brier score: 2.1810 - val_auc: 0.8627 - lr: 0.0010
# Epoch 6/100
# 111/111 [==============================] - 32s 273ms/step - loss: 1.6440 - accuracy: 0.5277 - top5-acc: 0.8768 - Brier score: 8.1350 - auc: 0.7228 - val_loss: 1.4415 - val_accuracy: 0.5991 - val_top5-acc: 0.9173 - val_Brier score: 2.2239 - val_auc: 0.8840 - lr: 0.0010
history = run_experiment(mixup_ds, val_ds_v, distiller, model_name='distiller')
# Out:
# Epoch 1/100
# 111/111 [==============================] - 54s 254ms/step - accuracy: 0.1583 - top5-acc: 0.5215 - Brier score: 12.9661 - auc: 0.6147 - student_loss: 4.1367 - distillation_loss: 6.4138 - val_accuracy: 0.2718 - val_top5-acc: 0.6920 - val_Brier score: 0.2793 - val_auc: 0.7565 - val_student_loss: 2.4706 - lr: 0.0010
# Epoch 2/100
# 111/111 [==============================] - 28s 235ms/step - accuracy: 0.2664 - top5-acc: 0.6744 - Brier score: 2.0977 - auc: 0.6731 - student_loss: 2.4487 - distillation_loss: 2.2391 - val_accuracy: 0.4145 - val_top5-acc: 0.7622 - val_Brier score: 0.3359 - val_auc: 0.8030 - val_student_loss: 2.0963 - lr: 0.0010
# Epoch 3/100
# 111/111 [==============================] - 28s 236ms/step - accuracy: 0.3465 - top5-acc: 0.7517 - Brier score: 2.0842 - auc: 0.7085 - student_loss: 2.1040 - distillation_loss: 1.9048 - val_accuracy: 0.4281 - val_top5-acc: 0.8109 - val_Brier score: 0.6629 - val_auc: 0.8235 - val_student_loss: 2.0225 - lr: 0.0010
# Epoch 4/100
# 111/111 [==============================] - 27s 228ms/step - accuracy: 0.3870 - top5-acc: 0.7976 - Brier score: 2.2621 - auc: 0.7130 - student_loss: 1.9758 - distillation_loss: 1.7524 - val_accuracy: 0.5345 - val_top5-acc: 0.8539 - val_Brier score: 0.6668 - val_auc: 0.8564 - val_student_loss: 1.6934 - lr: 0.0010
# Epoch 5/100
# 111/111 [==============================] - 27s 228ms/step - accuracy: 0.4363 - top5-acc: 0.8182 - Brier score: 2.3480 - auc: 0.7235 - student_loss: 1.8843 - distillation_loss: 1.6640 - val_accuracy: 0.5459 - val_top5-acc: 0.8777 - val_Brier score: 0.8175 - val_auc: 0.8642 - val_student_loss: 1.3743 - lr: 0.0010
# Epoch 6/100
# 111/111 [==============================] - 28s 235ms/step - accuracy: 0.4802 - top5-acc: 0.8582 - Brier score: 2.5108 - auc: 0.7238 - student_loss: 1.7513 - distillation_loss: 1.5519 - val_accuracy: 0.5900 - val_top5-acc: 0.8969 - val_Brier score: 0.8123 - val_auc: 0.8746 - val_student_loss: 1.5444 - lr: 0.0010
# Epoch 7/100
# 111/111 [==============================] - 27s 228ms/step - accuracy: 0.5238 - top5-acc: 0.8723 - Brier score: 2.8099 - auc: 0.7295 - student_loss: 1.6523 - distillation_loss: 1.4631 - val_accuracy: 0.6523 - val_top5-acc: 0.9117 - val_Brier score: 0.9032 - val_auc: 0.8795 - val_student_loss: 1.3063 - lr: 0.0010
# Epoch 8/100
# 111/111 [==============================] - 27s 227ms/step - accuracy: 0.5634 - top5-acc: 0.8805 - Brier score: 3.2662 - auc: 0.7094 - student_loss: 1.5509 - distillation_loss: 1.3639 - val_accuracy: 0.6693 - val_top5-acc: 0.9026 - val_Brier score: 1.4216 - val_auc: 0.8244 - val_student_loss: 1.6137 - lr: 0.0010
# Epoch 9/100
# 111/111 [==============================] - 27s 228ms/step - accuracy: 0.6076 - top5-acc: 0.8950 - Brier score: 3.4067 - auc: 0.7203 - student_loss: 1.4690 - distillation_loss: 1.2904 - val_accuracy: 0.6557 - val_top5-acc: 0.9083 - val_Brier score: 1.4503 - val_auc: 0.8355 - val_student_loss: 1.4844 - lr: 0.0010
# Epoch 10/100
# 111/111 [==============================] - 27s 228ms/step - accuracy: 0
- val_accuracy: 0.7622 - val_top5-acc: 0.9547 - val_Brier score: 2.1404 - val_auc: 0.8289 - val_student_loss: 0.8118 - lr: 2.0480e-11
# Epoch 52/100
# 111/111 [==============================] - 27s 228ms/step - accuracy: 0.7961 - top5-acc: 0.9657 - Brier score: 4.4416 - auc: 0.7099 - student_loss: 0.9672 - distillation_loss: 0.8030 - val_accuracy: 0.7622 - val_top5-acc: 0.9547 - val_Brier score: 2.1404 - val_auc: 0.8289 - val_student_loss: 1.0842 - lr: 2.0480e-11
# Epoch 53/100
# 111/111 [==============================] - 29s 239ms/step - accuracy: 0.7993 - top5-acc: 0.9657 - Brier score: 4.4787 - auc: 0.7141 - student_loss: 0.9661 - distillation_loss: 0.7953 - val_accuracy: 0.7622 - val_top5-acc: 0.9547 - val_Brier score: 2.1404 - val_auc: 0.8289 - val_student_loss: 1.0939 - lr: 2.0480e-11

# %%
plot_training_curves(history, 'Student (Tripartite Transformer- MixUp)', model_name='student')

# %% [markdown]
# ### ▶ AugPip

# %%
history = run_experiment(augpip_ds, val_ds_v, transformer_teacher, model_name='teacher')
# Out:
# Epoch 1/100
# 111/111 [==============================] - 100s 696ms/step - loss: 7.1333 - accuracy: 0.0991 - top5-acc: 0.3933 - Brier score: 36.6616 - auc: 0.5430 - val_loss: 2.9577 - val_accuracy: 0.1325 - val_top5-acc: 0.4485 - val_Brier score: 1.2952 - val_auc: 0.6165 - lr: 0.0010
# Epoch 2/100
# 111/111 [==============================] - 80s 698ms/step - loss: 2.9404 - accuracy: 0.1096 - top5-acc: 0.4318 - Brier score: 1.5452 - auc: 0.5614 - val_loss: 2.4051 - val_accuracy: 0.2525 - val_top5-acc: 0.6217 - val_Brier score: 1.0024 - val_auc: 0.7196 - lr: 0.0010
# Epoch 3/100
# 111/111 [==============================] - 80s 698ms/step - loss: 2.7588 - accuracy: 0.1317 - top5-acc: 0.4459 - Brier score: 1.2614 - auc: 0.5722 - val_loss: 2.4047 - val_accuracy: 0.2525 - val_top5-acc: 0.6455 - val_Brier score: 0.6772 - val_auc: 0.7199 - lr: 0.0010
# Epoch 4/100
# 111/111 [==============================] - 80s 700ms/step - loss: 2.5951 - accuracy: 0.1634 - top5-acc: 0.5040 - Brier score: 1.6986 - auc: 0.5888 - val_loss: 2.5897 - val_accuracy: 0.2469 - val_top5-acc: 0.5980 - val_Brier score: 1.6737 - val_auc: 0.6853 - lr: 0.0010
# Epoch 5/100
# 111/111 [==============================] - 80s 701ms/step - loss: 2.6229 - accuracy: 0.1636 - top5-acc: 0.5156 - Brier score: 2.1187 - auc: 0.5953 - val_loss: 2.2055 - val_accuracy: 0.3035 - val_top5-acc: 0.7225 - val_Brier score: 1.3341 - val_auc: 0.7618 - lr: 0.0010
# Epoch 6/100
# 111/111 [==============================] - 80s 703ms/step - loss: 2.6486 - accuracy: 0.1738 - top5-acc: 0.5501 - Brier score: 2.2504 - auc: 0.6052 - val_loss: 2.0774 - val_accuracy: 0.3726 - val_top5-acc: 0.7939 - val_Brier score: 1.6266 - val_auc: 0.7941 - lr: 0.0010
# Epoch 7/100
# Epoch 63/100
# 111/111 [==============================] - 82s 717ms/step - loss: 1.2886 - accuracy: 0.6693 - top5-acc: 0.9074 - Brier score: 2.1880 - auc: 0.7548 - val_loss: 0.7615 - val_accuracy: 0.7848 - val_top5-acc: 0.9740 - val_Brier score: 2.2165 - val_auc: 0.9555 - lr: 1.6000e-06
# Epoch 64/100
# 111/111 [==============================] - 82s 720ms/step - loss: 1.2993 - accuracy: 0.6656 - top5-acc: 0.9100 - Brier score: 2.1033 - auc: 0.7558 - val_loss: 0.7743 - val_accuracy: 0.7837 - val_top5-acc: 0.9740 - val_Brier score: 2.0857 - val_auc: 0.9564 - lr: 3.2000e-07
# Epoch 65/100
# 111/111 [==============================] - 83s 723ms/step - loss: 1.3157 - accuracy: 0.6520 - top5-acc: 0.8986 - Brier score: 1.9410 - auc: 0.7539 - val_loss: 0.7876 - val_accuracy: 0.7837 - val_top5-acc: 0.9740 - val_Brier score: 1.9655 - val_auc: 0.9570 - lr: 3.2000e-07
# Epoch 66/100
# 111/111 [==============================] - 83s 724ms/step - loss: 1.2777 - accuracy: 0.6772 - top5-acc: 0.9131 - Brier score: 1.9059 - auc: 0.7560 - val_loss: 0.8015 - val_accuracy: 0.7814 - val_top5-acc: 0.9740 - val_Brier score: 1.8528 - val_auc: 0.9576 - lr: 3.2000e-07
# Epoch 67/100
# 111/111 [==============================] - 82s 719ms/step - loss: 1.3254 - accuracy: 0.6619 - top5-acc: 0.9159 - Brier score: 1.6985 - auc: 0.7624 - val_loss: 0.8171 - val_accuracy: 0.7803 - val_top5-acc: 0.9740 - val_Brier score: 1.7395 - val_auc: 0.9580 - lr: 6.4000e-08
# Epoch 68/100
# 111/111 [==============================] - 81s 710ms/step - loss: 1.3415 - accuracy: 0.6736 - top5-acc: 0.9117 - Brier score: 1.6525 - auc: 0.7615 - val_loss: 0.8335 - val_accuracy: 0.7803 - val_top5-acc: 0.9740 - val_Brier score: 1.6327 - val_auc: 0.9588 - lr: 6.4000e-08
# Epoch 69/100
# 111/111 [==============================] - 80s 704ms/step - loss: 1.4076 - accuracy: 0.6696 - top5-acc: 0.9071 - Brier score: 1.5146 - auc: 0.7636 - val_loss: 0.8508 - val_accuracy: 0.7792 - val_top5-acc: 0.9740 - val_Brier score: 1.5319 - val_auc: 0.9592 - lr: 6.4000e-08

# %%
plot_training_curves(history, 'Teatcher (Tripartite Transformer- AugPip)', model_name='teacher')

# %%
distiller = Distiller(student=transformer_student, teacher=transformer_teacher)
history = run_experiment(augpip_ds, val_ds_v, distiller, model_name='distiller')
# Out:
# Epoch 1/100
# 111/111 [==============================] - 98s 642ms/step - accuracy: 0.1215 - top5-acc: 0.4595 - Brier score: 8.4342 - auc: 0.5863 - student_loss: 3.7669 - distillation_loss: 3.8488 - val_accuracy: 0.2299 - val_top5-acc: 0.6535 - val_Brier score: 0.1618 - val_auc: 0.7378 - val_student_loss: 2.4599 - lr: 0.0010
# 111/111 [==============================] - 79s 688ms/step - accuracy: 0.4773 - top5-acc: 0.8446 - Brier score: 1.9201 - auc: 0.7108 - student_loss: 1.8391 - distillation_loss: 0.4986 - val_accuracy: 0.6546 - val_top5-acc: 0.9264 - val_Brier score: 1.7541 - val_auc: 0.8457 - val_student_loss: 1.4416 - lr: 3.2000e-07
# Epoch 28/100
# 111/111 [==============================] - 79s 694ms/step - accuracy: 0.4666 - top5-acc: 0.8352 - Brier score: 1.8404 - auc: 0.6995 - student_loss: 1.8701 - distillation_loss: 0.4993 - val_accuracy: 0.6546 - val_top5-acc: 0.9264 - val_Brier score: 1.7544 - val_auc: 0.8458 - val_student_loss: 1.3867 - lr: 3.2000e-07
# Epoch 29/100
# 111/111 [==============================] - 80s 700ms/step - accuracy: 0.4575 - top5-acc: 0.8324 - Brier score: 1.8520 - auc: 0.7003 - student_loss: 1.8691 - distillation_loss: 0.5172 - val_accuracy: 0.6546 - val_top5-acc: 0.9264 - val_Brier score: 1.7543 - val_auc: 0.8459 - val_student_loss: 1.0787 - lr: 3.2000e-07

# %%
plot_training_curves(history, 'Student (Tripartite Transformer- AugPip)', model_name='student')

# %% [markdown]
# ### ▶ AugPip v2

# %%
##### NEW ########
import random
def aug_pipeline_v2(samples):
    samples = augmix(samples, training=True)
    r = random.randint(0, 1)
    if(r>0.5):
      samples = mixup(samples, training=True)
    else:
      samples = cutmix(samples, training=True)
    return samples
#AugPip
augpip_ds_v2 = train_ds.shuffle(1000).map(to_dict)
augpip_ds_v2 = augpip_ds_v2.map(aug_pipeline_v2)
augpip_ds_v2 = augpip_ds_v2.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
augpip_ds_v2 = augpip_ds_v2.prefetch(AUTOTUNE) #Use this for fit

# %%
history = run_experiment(augpip_ds_v2, val_ds_v, transformer_teacher, model_name='teacher')
# Out:
# Epoch 1/100
# 111/111 [==============================] - 100s 745ms/step - loss: 3.3561 - accuracy: 0.1413 - top5-acc: 0.4663 - Brier score: 4.7157 - auc: 0.5814 - val_loss: 2.6111 - val_accuracy: 0.1631 - val_top5-acc: 0.3986 - val_Brier score: 1.1632 - val_auc: 0.5742 - lr: 0.0010
# Epoch 2/100
# 111/111 [==============================] - 77s 676ms/step - loss: 2.8440 - accuracy: 0.1424 - top5-acc: 0.4547 - Brier score: 2.8613 - auc: 0.5716 - val_loss: 2.4765 - val_accuracy: 0.2186 - val_top5-acc: 0.5277 - val_Brier score: 1.7230 - val_auc: 0.6703 - lr: 0.0010
# Epoch 3/100
# 111/111 [==============================] - 77s 672ms/step - loss: 2.6847 - accuracy: 0.1685 - top5-acc: 0.5028 - Brier score: 4.9881 - auc: 0.5913 - val_loss: 2.4408 - val_accuracy: 0.2356 - val_top5-acc: 0.5651 - val_Brier score: 1.3544 - val_auc: 0.6770 - lr: 0.0010
# Epoch 4/100
# 111/111 [==============================] - 77s 671ms/step - loss: 2.5865 - accuracy: 0.1883 - top5-acc: 0.5343 - Brier score: 4.9241 - auc: 0.6031 - val_loss: 2.2324 - val_accuracy: 0.2831 - val_top5-acc: 0.7282 - val_Brier score: 2.1570 - val_auc: 0.7596 - lr: 0.0010
# Epoch 79/100
# 111/111 [==============================] - 77s 670ms/step - loss: 0.7839 - accuracy: 0.8616 - top5-acc: 0.9728 - Brier score: 5.4875 - auc: 0.7846 - val_loss: 0.6348 - val_accuracy: 0.8211 - val_top5-acc: 0.9785 - val_Brier score: 3.8811 - val_auc: 0.9664 - lr: 3.2000e-07
# Epoch 80/100
# 111/111 [==============================] - 76s 664ms/step - loss: 0.8048 - accuracy: 0.8454 - top5-acc: 0.9700 - Brier score: 5.0918 - auc: 0.7842 - val_loss: 0.6484 - val_accuracy: 0.8188 - val_top5-acc: 0.9785 - val_Brier score: 3.6292 - val_auc: 0.9662 - lr: 6.4000e-08
# Epoch 81/100
# 111/111 [==============================] - 76s 662ms/step - loss: 0.8064 - accuracy: 0.8505 - top5-acc: 0.9717 - Brier score: 4.9028 - auc: 0.7864 - val_loss: 0.6641 - val_accuracy: 0.8154 - val_top5-acc: 0.9785 - val_Brier score: 3.4039 - val_auc: 0.9668 - lr: 6.4000e-08
# Epoch 82/100
# 111/111 [==============================] - 77s 668ms/step - loss: 0.8690 - accuracy: 0.8372 - top5-acc: 0.9638 - Brier score: 4.5232 - auc: 0.7883 - val_loss: 0.6816 - val_accuracy: 0.8143 - val_top5-acc: 0.9785 - val_Brier score: 3.2055 - val_auc: 0.9667 - lr: 6.4000e-08

# %%
plot_training_curves(history, 'Teatcher (Tripartite Transformer- AugPip)', model_name='teacher')

# %%
distiller = Distiller(student=transformer_student, teacher=transformer_teacher)
history = run_experiment(augpip_ds_v2, val_ds_v, distiller, model_name='distiller')
# Out:
# Epoch 1/100
# 111/111 [==============================] - 94s 606ms/step - accuracy: 0.1441 - top5-acc: 0.4841 - Brier score: 7.8657 - auc: 0.6011 - student_loss: 3.8694 - distillation_loss: 4.8957 - val_accuracy: 0.2616 - val_top5-acc: 0.7146 - val_Brier score: 0.2198 - val_auc: 0.7768 - val_student_loss: 2.4313 - lr: 0.0010
# Epoch 2/100
# 111/111 [==============================] - 75s 659ms/step - accuracy: 0.2302 - top5-acc: 0.6257 - Brier score: 1.6394 - auc: 0.6631 - student_loss: 2.4598 - distillation_loss: 1.7604 - val_accuracy: 0.3533 - val_top5-acc: 0.8279 - val_Brier score: 0.6327 - val_auc: 0.8260 - val_student_loss: 2.0407 - lr: 0.0010
# Epoch 3/100
# 111/111 [==============================] - 75s 650ms/step - accuracy: 0.2908 - top5-acc: 0.7095 - Brier score: 1.7385 - auc: 0.6907 - student_loss: 2.2607 - distillation_loss: 1.5372 - val_accuracy: 0.4757 - val_top5-acc: 0.8573 - val_Brier score: 0.6759 - val_auc: 0.8557 - val_student_loss: 1.7345 - lr: 0.0010
# Epoch 4/100
# 111/111 [==============================] - 75s 653ms/step - accuracy: 0.3624 - top5-acc: 0.7602 - Brier score: 1.9001 - auc: 0.7068 - student_loss: 2.0851 - distillation_loss: 1.3874 - val_accuracy: 0.5300 - val_top5-acc: 0.8822 - val_Brier score: 0.7535 - val_auc: 0.8679 - val_student_loss: 1.3081 - lr: 0.0010
# Epoch 5/100
# 111/111 [==============================] - 75s 654ms/step - accuracy: 0.3785 - top5-acc: 0.7885 - Brier score: 2.0727 - auc: 0.7096 - student_loss: 2.0029 - distillation_loss: 1.3093 - val_accuracy: 0.5085 - val_top5-acc: 0.8822 - val_Brier score: 1.0143 - val_auc: 0.8606 - val_student_loss: 1.5799 - lr: 0.0010
# Epoch 6/100
# 111/111 [==============================] - 75s 650ms/step - accuracy: 0.4230 - top5-acc: 0.8032 - Brier score: 2.1165 - auc: 0.7114 - student_loss: 1.9152 - distillation_loss: 1.1823 - val_accuracy: 0.5787 - val_top5-acc: 0.8913 - val_Brier score: 1.2902 - val_auc: 0.8528 - val_student_loss: 1.4064 - lr: 2.0000e-04
# Epoch 7/100
# 111/111 [==============================] - 75s 658ms/step - accuracy: 0.4615 - top5-acc: 0.8409 - Brier score: 2.2730 - auc: 0.7189 - student_loss: 1.7967 - distillation_loss: 1.0985 - val_accuracy: 0.5923 - val_top5-acc: 0.9015 - val_Brier score: 1.4505 - val_auc: 0.8554 - val_student_loss: 1.4542 - lr: 2.0000e-04
# Epoch 8/100
# 111/111 [==============================] - 75s 659ms/step - accuracy: 0.4844 - top5-acc: 0.8429 - Brier score: 2.3230 - auc: 0.7179 - student_loss: 1.7401 - distillation_loss: 1.0488 - val_accuracy: 0.6048 - val_top5-acc: 0.9083 - val_Brier score: 1.5941 - val_auc: 0.8545 - val_student_loss: 1.5670 - lr: 2.0000e-04
# Epoch 9/100
# 111/111 [==============================] - 75s 656ms/step - accuracy: 0.5071 - top5-acc: 0.8516 - Brier score: 2.4718 - auc: 0.7229 - student_loss: 1.6896 - distillation_loss: 1.0133 - val_accuracy: 0.6217 - val_top5-acc: 0.9207 - val_Brier score: 1.7542 - val_auc: 0.8570 - val_student_loss: 1.2403 - lr: 2.0000e-04
# Epoch 10/100
# 111/111 [==============================] - 76s 659ms/step - accuracy: 0.5093 - top5-acc: 0.8545 - Brier score: 2.4883 - auc: 0.7243 - student_loss: 1.6629 - distillation_loss: 0.9797 - val_accuracy: 0.6523 - val_top5-acc: 0.9196 - val_Brier score: 1.8257 - val_auc: 0.8519 - val_student_loss: 1.1976 - lr: 2.0000e-04
# Epoch 11/100
# 111/111 [==============================] - 75s 659ms/step - accuracy: 0.5357 - top5-acc: 0.8621 - Brier score: 2.5089 - auc: 0.7314 - student_loss: 1.6198 - distillation_loss: 0.9380 - val_accuracy: 0.6557 - val_top5-acc: 0.9275 - val_Brier score: 1.5820 - val_auc: 0.8649 - val_student_loss: 0.9442 - lr: 2.0000e-04
# Epoch 12/100
# 111/111 [==============================] - 75s 658ms/step - accuracy: 0.5292 - top5-acc: 0.8675 - Brier score: 2.5377 - auc: 0.7218 - student_loss: 1.6016 - distillation_loss: 0.9170 - val_accuracy: 0.6591 - val_top5-acc: 0.9287 - val_Brier score: 1.6341 - val_auc: 0.8646 - val_student_loss: 1.1432 - lr: 2.0000e-04
# Epoch 13/100
# Epoch 38/100
# 111/111 [==============================] - 76s 663ms/step - accuracy: 0.6713 - top5-acc: 0.9176 - Brier score: 3.2616 - auc: 0.7214 - student_loss: 1.2858 - distillation_loss: 0.7007 - val_accuracy: 0.7554 - val_top5-acc: 0.9570 - val_Brier score: 2.2821 - val_auc: 0.8413 - val_student_loss: 0.6733 - lr: 1.2800e-08
# Epoch 39/100
# 111/111 [==============================] - 74s 648ms/step - accuracy: 0.6863 - top5-acc: 0.9292 - Brier score: 3.2385 - auc: 0.7267 - student_loss: 1.2739 - distillation_loss: 0.6882 - val_accuracy: 0.7554 - val_top5-acc: 0.9570 - val_Brier score: 2.2822 - val_auc: 0.8413 - val_student_loss: 1.1532 - lr: 1.2800e-08
# Epoch 40/100
# 111/111 [==============================] - 75s 655ms/step - accuracy: 0.7050 - top5-acc: 0.9284 - Brier score: 3.2450 - auc: 0.7214 - student_loss: 1.2450 - distillation_loss: 0.6799 - val_accuracy: 0.7554 - val_top5-acc: 0.9570 - val_Brier score: 2.2822 - val_auc: 0.8413 - val_student_loss: 0.8263 - lr: 2.5600e-09
# Epoch 41/100
# 111/111 [==============================] - 75s 654ms/step - accuracy: 0.6863 - top5-acc: 0.9238 - Brier score: 3.1792 - auc: 0.7242 - student_loss: 1.2548 - distillation_loss: 0.6722 - val_accuracy: 0.7554 - val_top5-acc: 0.9570 - val_Brier score: 2.2822 - val_auc: 0.8413 - val_student_loss: 0.9420 - lr: 2.5600e-09
# Epoch 42/100
# 111/111 [==============================] - 75s 653ms/step - accuracy: 0.6787 - top5-acc: 0.9202 - Brier score: 3.1723 - auc: 0.7266 - student_loss: 1.2915 - distillation_loss: 0.6847 - val_accuracy: 0.7554 - val_top5-acc: 0.9570 - val_Brier score: 2.2822 - val_auc: 0.8413 - val_student_loss: 1.0248 - lr: 2.5600e-09
# Epoch 43/100
# 111/111 [==============================] - 75s 656ms/step - accuracy: 0.6857 - top5-acc: 0.9247 - Brier score: 3.2484 - auc: 0.7273 - student_loss: 1.2641 - distillation_loss: 0.6663 - val_accuracy: 0.7554 - val_top5-acc: 0.9570 - val_Brier score: 2.2822 - val_auc: 0.8413 - val_student_loss: 0.9657 - lr: 5.1200e-10
# Epoch 44/100
# 111/111 [==============================] - 75s 656ms/step - accuracy: 0.6846 - top5-acc: 0.9221 - Brier score: 3.1826 - auc: 0.7264 - student_loss: 1.2730 - distillation_loss: 0.7003 - val_accuracy: 0.7554 - val_top5-acc: 0.9570 - val_Brier score: 2.2822 - val_auc: 0.8413 - val_student_loss: 0.8023 - lr: 5.1200e-10
# Epoch 45/100
# 111/111 [==============================] - 76s 665ms/step - accuracy: 0.6778 - top5-acc: 0.9199 - Brier score: 3.2005 - auc: 0.7199 - student_loss: 1.2937 - distillation_loss: 0.6830 - val_accuracy: 0.7554 - val_top5-acc: 0.9570 - val_Brier score: 2.2822 - val_auc: 0.8413 - val_student_loss: 0.9014 - lr: 5.1200e-10

# %%
plot_training_curves(history, 'Student (Tripartite Transformer- AugPip)', model_name='student')

# %% [markdown]
# ---
